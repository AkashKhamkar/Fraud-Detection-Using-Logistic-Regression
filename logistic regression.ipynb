# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression

# %%
train_iden = pd.read_csv("data/train_identity.csv")
train_trans = pd.read_csv("data\train_transaction.csv")
test_trans = pd.read_csv("data\test_transaction.csv")
test_iden = pd.read_csv("data\test_identity.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-85-bca637a7135e> in <module>()
#       1 train_iden = pd.read_csv("data/train_identity.csv")
# ----> 2 train_trans = pd.read_csv("data\train_transaction.csv")
#       3 test_trans = pd.read_csv("data\test_transaction.csv")
#       4 test_iden = pd.read_csv("data\test_identity.csv")
#
# ...

# %%
train_iden.head()
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1        2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2        2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3        2987011   -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 4        2987016    0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
#
#    id_09              ...                              id_31  id_32  \
# 0    NaN              ...                samsung browser 6.2   32.0
# 1    NaN              ...                 mobile safari 11.0   32.0
# 2    0.0              ...                        chrome 62.0    NaN
# 3    NaN              ...                        chrome 62.0    NaN
# 4    0.0              ...                        chrome 62.0   24.0
#
#        id_33           id_34  id_35 id_36 id_37  id_38  DeviceType  \
# ...

# %%
test_trans.head(50)
# Out:
#     TransactionID  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# 0         3663549       18403224          31.950         W  10409  111.0
# 1         3663550       18403263          49.000         W   4272  111.0
# 2         3663551       18403310         171.000         W   4476  574.0
# 3         3663552       18403310         284.950         W  10989  360.0
# 4         3663553       18403317          67.950         W  18018  452.0
# 5         3663554       18403323          57.950         W  12839  321.0
# 6         3663555       18403350          87.000         W  16560  476.0
# 7         3663556       18403387         390.000         W  15066  170.0
# 8         3663557       18403405         103.950         W   2803  100.0
# 9         3663558       18403416         117.000         W  12544  321.0
# 10        3663559       18403474         261.950         W  16982  127.0
# 11        3663560       18403504         107.950         W   9500  321.0
# ...

# %%
train=pd.merge(train_trans,train_iden,how="left",on="TransactionID")
test=pd.merge(test_trans,test_iden,how="left",on="TransactionID")

# %%
train.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
#
#    card2  card3       card4  card5              ...                \
# 0    NaN  150.0    discover  142.0              ...
# 1  404.0  150.0  mastercard  102.0              ...
# 2  490.0  150.0        visa  166.0              ...
# 3  567.0  150.0  mastercard  117.0              ...
# 4  514.0  150.0  mastercard  102.0              ...
#
#                  id_31  id_32      id_33           id_34  id_35 id_36 id_37  \
# 0                  NaN    NaN        NaN             NaN    NaN   NaN   NaN
# ...

# %%
test.head()
# Out:
#    TransactionID  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# 0        3663549       18403224           31.95         W  10409  111.0
# 1        3663550       18403263           49.00         W   4272  111.0
# 2        3663551       18403310          171.00         W   4476  574.0
# 3        3663552       18403310          284.95         W  10989  360.0
# 4        3663553       18403317           67.95         W  18018  452.0
#
#    card3       card4  card5  card6     ...      id_31  id_32  id_33  id_34  \
# 0  150.0        visa  226.0  debit     ...        NaN    NaN    NaN    NaN
# 1  150.0        visa  226.0  debit     ...        NaN    NaN    NaN    NaN
# 2  150.0        visa  226.0  debit     ...        NaN    NaN    NaN    NaN
# 3  150.0        visa  166.0  debit     ...        NaN    NaN    NaN    NaN
# 4  150.0  mastercard  117.0  debit     ...        NaN    NaN    NaN    NaN
#
#   id_35 id_36  id_37  id_38  DeviceType  DeviceInfo
# ...

# %%
train.dtypes
# Out:
# TransactionID       int64
# isFraud             int64
# TransactionDT       int64
# TransactionAmt    float64
# ProductCD          object
# card1               int64
# card2             float64
# card3             float64
# card4              object
# card5             float64
# card6              object
# addr1             float64
# addr2             float64
# dist1             float64
# dist2             float64
# P_emaildomain      object
# R_emaildomain      object
# C1                float64
# C2                float64
# C3                float64
# C4                float64
# C5                float64
# C6                float64
# C7                float64
# C8                float64
# C9                float64
# C10               float64
# C11               float64
# C12               float64
# C13               float64
#                    ...
# id_11             float64
# id_12              object
# id_13             float64
# id_14             float64
# ...

# %%
for col_name in train.columns:
    if train[col_name].dtypes == 'object' :
        unique_cat = len(train[col_name].unique())
        print("Feature '{col_name}' has {unique_cat} categories".format(col_name=col_name, unique_cat=unique_cat))
# Out:
# Feature 'ProductCD' has 5 categories
# Feature 'card4' has 5 categories
# Feature 'card6' has 5 categories
# Feature 'P_emaildomain' has 60 categories
# Feature 'R_emaildomain' has 61 categories
# Feature 'M1' has 3 categories
# Feature 'M2' has 3 categories
# Feature 'M3' has 3 categories
# Feature 'M4' has 4 categories
# Feature 'M5' has 3 categories
# Feature 'M6' has 3 categories
# Feature 'M7' has 3 categories
# Feature 'M8' has 3 categories
# Feature 'M9' has 3 categories
# Feature 'id_12' has 3 categories
# Feature 'id_15' has 4 categories
# Feature 'id_16' has 3 categories
# Feature 'id_23' has 4 categories
# Feature 'id_27' has 3 categories
# Feature 'id_28' has 3 categories
# Feature 'id_29' has 3 categories
# Feature 'id_30' has 76 categories
# Feature 'id_31' has 131 categories
# Feature 'id_33' has 261 categories
# Feature 'id_34' has 5 categories
# Feature 'id_35' has 3 categories
# Feature 'id_36' has 3 categories
# Feature 'id_37' has 3 categories
# ...

# %%
train.describe().transpose()
# Out:
#                    count          mean           std          min  \
# TransactionID   590540.0  3.282270e+06  1.704744e+05  2987000.000
# isFraud         590540.0  3.499001e-02  1.837546e-01        0.000
# TransactionDT   590540.0  7.372311e+06  4.617224e+06    86400.000
# TransactionAmt  590540.0  1.350272e+02  2.391625e+02        0.251
# card1           590540.0  9.898735e+03  4.901170e+03     1000.000
# card2           581607.0  3.625555e+02  1.577932e+02      100.000
# card3           588975.0  1.531949e+02  1.133644e+01      100.000
# card5           586281.0  1.992789e+02  4.124445e+01      100.000
# addr1           524834.0  2.907338e+02  1.017411e+02      100.000
# addr2           524834.0  8.680063e+01  2.690623e+00       10.000
# dist1           238269.0  1.185022e+02  3.718720e+02        0.000
# dist2            37627.0  2.318554e+02  5.290535e+02        0.000
# C1              590540.0  1.409246e+01  1.335690e+02        0.000
# ...

# %%
cat_cols = [col for col in train.columns if train[col].dtype in ['object']]
train[cat_cols].describe()
# Out:
#        ProductCD   card4   card6 P_emaildomain R_emaildomain      M1      M2  \
# count     590540  588963  588969        496084        137291  319440  319440
# unique         5       4       4            59            60       2       2
# top            W    visa   debit     gmail.com     gmail.com       T       T
# freq      439670  384767  439938        228355         57147  319415  285468
#
#             M3      M4      M5    ...           id_30        id_31      id_33  \
# count   319440  309096  240058    ...           77565       140282      73289
# unique       2       3       2    ...              75          130        260
# top          T      M0       F    ...      Windows 10  chrome 63.0  1920x1080
# freq    251731  196405  132491    ...           21155        22000      16874
#
#                  id_34   id_35   id_36   id_37   id_38 DeviceType DeviceInfo
# count            77805  140985  140985  140985  140985     140810     118666
# ...

# %%
# Visualize target variable.(isFraud)
sns.countplot(train['isFraud'])
print("Count Plot for Fraudulent vs legitimate transaction") ## Imbalanced Dataset
train['isFraud'].value_counts(normalize=True) * 100
# Out:
# Count Plot for Fraudulent vs legitimate transaction
# 0    96.500999
# 1     3.499001
# Name: isFraud, dtype: float64

# %%
perc_fraud = len(train[train['isFraud']==1].index)*100/train.shape[0]
print("Percentage of Fradaulent records in dataset {:.2f}".format(perc_fraud) )
# Out:
# Percentage of Fradaulent records in dataset 3.50

# %%
# Check missing data - Many Columns have more than 50% NA/Null records
def missing_data(df) :
    count = df.isnull().sum()
    percent = (df.isnull().sum()) / (df.isnull().count()) * 100
    total = pd.concat([count, percent], axis=1, keys = ['Count', 'Percent'])
    types = []
    for col in df.columns :
        dtypes = str(df[col].dtype)
        types.append(dtypes)
    total['dtypes'] = types
    
    return np.transpose(total)

missing_data(train)
# Out:
#         TransactionID isFraud TransactionDT TransactionAmt ProductCD  card1  \
# Count               0       0             0              0         0      0
# Percent             0       0             0              0         0      0
# dtypes          int64   int64         int64        float64    object  int64
#
#            card2     card3     card4     card5    ...        id_31    id_32  \
# Count       8933      1565      1577      4259    ...       450258   512954
# Percent  1.51268  0.265012  0.267044  0.721204    ...      76.2451  86.8619
# dtypes   float64   float64    object   float64    ...       object  float64
#
#            id_33    id_34    id_35    id_36    id_37    id_38 DeviceType  \
# Count     517251   512735   449555   449555   449555   449555     449730
# Percent  87.5895  86.8248  76.1261  76.1261  76.1261  76.1261    76.1557
# dtypes    object   object   object   object   object   object     object
#
#         DeviceInfo
# Count       471874
# ...

# %%
## WE will Drop columns with more 50% Null value.
null_percent = train.isnull().sum()/train.shape[0]*100

cols_to_drop = np.array(null_percent[null_percent > 50].index)

cols_to_drop
# Out:
# array(['dist1', 'dist2', 'R_emaildomain', 'D5', 'D6', 'D7', 'D8', 'D9',
#        'D12', 'D13', 'D14', 'M5', 'M7', 'M8', 'M9', 'V138', 'V139',
#        'V140', 'V141', 'V142', 'V143', 'V144', 'V145', 'V146', 'V147',
#        'V148', 'V149', 'V150', 'V151', 'V152', 'V153', 'V154', 'V155',
#        'V156', 'V157', 'V158', 'V159', 'V160', 'V161', 'V162', 'V163',
#        'V164', 'V165', 'V166', 'V167', 'V168', 'V169', 'V170', 'V171',
#        'V172', 'V173', 'V174', 'V175', 'V176', 'V177', 'V178', 'V179',
#        'V180', 'V181', 'V182', 'V183', 'V184', 'V185', 'V186', 'V187',
#        'V188', 'V189', 'V190', 'V191', 'V192', 'V193', 'V194', 'V195',
#        'V196', 'V197', 'V198', 'V199', 'V200', 'V201', 'V202', 'V203',
#        'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V210', 'V211',
#        'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V218', 'V219',
#        'V220', 'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227',
# ...

# %%
# Drop Columns (cols_to_drop) from train and test
train = train.drop(cols_to_drop, axis=1)
test = test.drop(cols_to_drop,axis=1)

# %%
print(train.shape)
print(test.shape)
# Out:
# (590540, 220)
# (506691, 219)

# %%
train = train.fillna(-999)
test = test.fillna(-999)

# %%
train_y = train['isFraud']
train_X = train.drop('isFraud', axis=1)

# %%
# Label Encoding for categorical variables.
for f in train_X.columns:
    if train_X[f].dtype=='object' or test[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(train_X[f].values) + list(test[f].values))
        train_X[f] = lbl.transform(list(train_X[f].values))
        test[f] = lbl.transform(list(test[f].values))

# %%
## Create Base Model - LogisticRegression

logreg = LogisticRegression(random_state=0,max_iter=260)
logreg.fit(train_X, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=260, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
submission = pd.read_csv('sample_submission.csv',index_col='TransactionID')
submission['isFraud'] = logreg.predict_proba(test_df)[:,1]
submission.head(10)
# Out:
#                 isFraud
# TransactionID
# 3663549        0.017358
# 3663550        0.019694
# 3663551        0.027907
# 3663552        0.028336
# 3663553        0.026413
# 3663554        0.022794
# 3663555        0.028148
# 3663556        0.019209
# 3663557        0.017286
# 3663558        0.024041
